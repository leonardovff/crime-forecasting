# %%
import pandas as pd

df_crimes = pd.read_csv(
    "./output/maceio/filtered_maceio_inside_polygon.csv",
    delimiter=";",
)

# %%
display(df_crimes)
df_crimes.info()
# Out:
#        LONGITUDE  LATITUDE          ROUBO_GROUP            DATA_HORA  \
# 0     -35.698388 -9.658217       street_robbery  2022-01-01 02:00:00
# 1     -35.703405 -9.660662       street_robbery  2022-01-01 02:00:00
# 2     -35.710142 -9.653007      vehicle_robbery  2022-01-01 02:00:00
# 3     -35.713147 -9.668955       street_robbery  2022-01-01 03:00:00
# 4     -35.703983 -9.663635       street_robbery  2022-01-01 04:00:00
# ...          ...       ...                  ...                  ...
# 72707 -35.756315 -9.662037       street_robbery  2014-12-22 12:50:00
# 72708 -35.715706 -9.652401      vehicle_robbery  2014-12-22 19:00:00
# 72709 -35.755908 -9.586733  residential_robbery  2014-12-23 05:30:00
# 72710 -35.738317 -9.624963       street_robbery  2014-12-23 09:30:00
# 72711 -35.739418 -9.630707      vehicle_robbery  2014-12-23 15:00:00
#
#       CIDADE_FATO
# 0          Maceió
# 1          Maceió
# 2          Maceió
# 3          Maceió
# 4          Maceió
# ...           ...
# 72707      Maceió
# 72708      Maceió
# 72709      Maceió
# 72710      Maceió
# 72711      Maceió
#
# [72712 rows x 5 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 72712 entries, 0 to 72711
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LONGITUDE    72712 non-null  float64
#  1   LATITUDE     72712 non-null  float64
#  2   ROUBO_GROUP  72712 non-null  str
#  3   DATA_HORA    72712 non-null  str
#  4   CIDADE_FATO  72712 non-null  str
# dtypes: float64(2), str(3)
# memory usage: 2.8 MB

# %%
from shapely.geometry import Point
import shapely.geometry
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
from pandarallel import pandarallel
import os

# Ensure at least 1 worker, handle case where os.cpu_count() returns None or 0
cpu_count = os.cpu_count() or 1
nb_workers = max(1, min(cpu_count, 20))
pandarallel.initialize(nb_workers=nb_workers, progress_bar=True)


def generate_grid(grid_size):
    mun = gpd.read_file("./output/maceio/osm_maceio.geojson")
    mun = mun.to_crs("EPSG:4326")
    gdf = mun[mun["name"] == "Maceió"].copy()

    bbox = gdf.total_bounds
    min_lon, min_lat, max_lon, max_lat = (bbox[2], bbox[1], bbox[0], bbox[3])

    lon = np.linspace(min_lon, max_lon, grid_size + 1)
    lat = np.linspace(min_lat, max_lat, grid_size + 1)

    latlons = []
    for i in range(len(lat) - 1):
        for k in range(len(lon) - 1):
            latlons.append((lat[k], lon[i], lat[k + 1], lon[i + 1]))

    m = folium.Map(
        location=((min_lat + max_lat) / 2, (min_lon + max_lon) / 2), zoom_start=11
    )
    for k in latlons:
        folium.Rectangle(
            [(k[0], k[1]), (k[2], k[3])], color="red", fill="pink", fill_opcity=0.5
        ).add_to(m)
    cgeo = (
        gdf.set_crs("epsg:4326")
        .sample(1)
        .pipe(lambda d: d.to_crs(d.estimate_utm_crs()))["geometry"]
        # .centroid.buffer(10000)
        .to_crs("epsg:4326")
        .__geo_interface__
    )

    geo_j = folium.GeoJson(data=cgeo)
    geo_j.add_to(m)
    m.save("./output/maceio/maceio_grids.html")

    return (min_lon, min_lat, max_lon, max_lat, latlons)


def find_polygon(row, df):
    for p_idx, elem in df.iterrows():
        if elem["polygon"].contains(Point(row["LONGITUDE"], row["LATITUDE"])):
            polygon_num = p_idx
            break
    return pd.Series({"cell": polygon_num})


# generate grid boxes
min_lon, min_lat, max_lon, max_lat, grid_bboxes = generate_grid(grid_size=39)

# turn boxes into polygons and that list into a dataframe
polygon_list = []
for elem in grid_bboxes:
    # elem is (min_lat, min_lon, max_lat, max_lon)
    polygon = shapely.geometry.box(elem[1], elem[0], elem[3], elem[2], ccw=True)
    polygon_list.append(polygon)
df_poly = pd.DataFrame(polygon_list, columns=["polygon"])


crimes_list = [
    "street_robbery",
    "vehicle_robbery",
    "public_transport_robbery",
    "commercial_robbery",
    "residential_robbery",
]
# generate file for each crime
print("Finding the grid cell for each point...")
df_final = df_crimes.merge(
    df_crimes.parallel_apply(find_polygon, df=df_poly, axis=1),
    left_index=True,
    right_index=True,
)

df_final.to_csv(f"./output/maceio/maceio_with_grid_index.csv", sep=";")
display(df_final.shape)
# Out:
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# Finding the grid cell for each point...
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=6060), Label(value='0 / 6060'))), …
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-5:
# Traceback (most recent call last):
# Process ForkPoolWorker-4:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
# Traceback (most recent call last):
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#         data,
#     ...<3 lines>...
#         extra,
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#         data,
#     ...<3 lines>...
#         extra,
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ~~~~~~~~~~^
#         user_defined_function,
#         ^^^^^^^^^^^^^^^^^^^^^^
#         *user_defined_function_args,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         **user_defined_function_kwargs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#         data,
#     ...<3 lines>...
#         extra,
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#         data,
#     ...<3 lines>...
#         extra,
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ~~~~~~~~~~^
#         user_defined_function,
#         ^^^^^^^^^^^^^^^^^^^^^^
#         *user_defined_function_args,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         **user_defined_function_kwargs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ~~~~~~~~~~^
#         user_defined_function,
#         ^^^^^^^^^^^^^^^^^^^^^^
#         *user_defined_function_args,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         **user_defined_function_kwargs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 12419, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#         data,
#     ...<3 lines>...
#         extra,
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ~~~~~~~~~~^
#         user_defined_function,
#         ^^^^^^^^^^^^^^^^^^^^^^
#         *user_defined_function_args,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         **user_defined_function_kwargs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#         data,
#     ...<3 lines>...
#         extra,
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 12419, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#         data,
#     ...<3 lines>...
#         extra,
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1015, in apply
#     return self.apply_standard()
#            ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 12419, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ~~~~~~~~~~^
#         user_defined_function,
#         ^^^^^^^^^^^^^^^^^^^^^^
#         *user_defined_function_args,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         **user_defined_function_kwargs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#         data,
#     ...<3 lines>...
#         extra,
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 12419, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#         data,
#     ...<3 lines>...
#         extra,
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#         data,
#     ...<3 lines>...
#         extra,
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ~~~~~~~~~~^
#         user_defined_function,
#         ^^^^^^^^^^^^^^^^^^^^^^
#         *user_defined_function_args,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         **user_defined_function_kwargs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1167, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ~~~~~~~~~~^
#         user_defined_function,
#         ^^^^^^^^^^^^^^^^^^^^^^
#         *user_defined_function_args,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         **user_defined_function_kwargs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1015, in apply
#     return self.apply_standard()
#            ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1015, in apply
#     return self.apply_standard()
#            ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 12419, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ~~~~~~~~~~^
#         user_defined_function,
#         ^^^^^^^^^^^^^^^^^^^^^^
#         *user_defined_function_args,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         **user_defined_function_kwargs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ~~~~~~~~~~^
#         user_defined_function,
#         ^^^^^^^^^^^^^^^^^^^^^^
#         *user_defined_function_args,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         **user_defined_function_kwargs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1015, in apply
#     return self.apply_standard()
#            ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ~~~~~~~~~~^
#         user_defined_function,
#         ^^^^^^^^^^^^^^^^^^^^^^
#         *user_defined_function_args,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         **user_defined_function_kwargs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#         data,
#     ...<3 lines>...
#         extra,
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 12419, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 12419, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1183, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1167, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1015, in apply
#     return self.apply_standard()
#            ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1167, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 12419, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 12419, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1167, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1015, in apply
#     return self.apply_standard()
#            ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 12419, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ~~~~~~~~~~^
#         user_defined_function,
#         ^^^^^^^^^^^^^^^^^^^^^^
#         *user_defined_function_args,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         **user_defined_function_kwargs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#         data,
#     ...<3 lines>...
#         extra,
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1015, in apply
#     return self.apply_standard()
#            ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#         *user_defined_function_args, **user_defined_functions_kwargs
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1167, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1183, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1183, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1183, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1015, in apply
#     return self.apply_standard()
#            ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1015, in apply
#     return self.apply_standard()
#            ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1167, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1015, in apply
#     return self.apply_standard()
#            ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 12419, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1167, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#            ~~~~~~~~~~^
#         user_defined_function,
#         ^^^^^^^^^^^^^^^^^^^^^^
#         *user_defined_function_args,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         **user_defined_function_kwargs,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/tmp/ipykernel_130682/2446021062.py", line 56, in find_polygon
#     for p_idx, elem in df.iterrows():
#                        ~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#         *user_defined_function_args, **user_defined_functions_kwargs
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1183, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#         *user_defined_function_args, **user_defined_functions_kwargs
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1167, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1167, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#         *user_defined_function_args, **user_defined_functions_kwargs
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1167, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1183, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1015, in apply
#     return self.apply_standard()
#            ~~~~~~~~~~~~~~~~~~~^^
#   File "/tmp/ipykernel_130682/2446021062.py", line 57, in find_polygon
#     if elem["polygon"].contains(Point(row["LONGITUDE"], row["LATITUDE"])):
#                                 ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1183, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 12419, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 1586, in iterrows
#     s = klass(v, index=columns, name=k).__finalize__(self)
#         ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#         *user_defined_function_args, **user_defined_functions_kwargs
#     )
#   File "/tmp/ipykernel_130682/2446021062.py", line 56, in find_polygon
#     for p_idx, elem in df.iterrows():
#                        ~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1183, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1183, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_130682/2446021062.py", line 57, in find_polygon
#     if elem["polygon"].contains(Point(row["LONGITUDE"], row["LATITUDE"])):
#                                 ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1183, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#         *user_defined_function_args, **user_defined_functions_kwargs
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/geometry/point.py", line 73, in __new__
#     coords = np.array(args).squeeze()
#              ~~~~~~~~^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/series.py", line 514, in __init__
#     data = sanitize_array(data, index, dtype, copy)
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#         *user_defined_function_args, **user_defined_functions_kwargs
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1015, in apply
#     return self.apply_standard()
#            ~~~~~~~~~~~~~~~~~~~^^
#   File "/tmp/ipykernel_130682/2446021062.py", line 57, in find_polygon
#     if elem["polygon"].contains(Point(row["LONGITUDE"], row["LATITUDE"])):
#                                 ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 1586, in iterrows
#     s = klass(v, index=columns, name=k).__finalize__(self)
#         ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1167, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#         *user_defined_function_args, **user_defined_functions_kwargs
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#         *user_defined_function_args, **user_defined_functions_kwargs
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#         *user_defined_function_args, **user_defined_functions_kwargs
#     )
# KeyboardInterrupt
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/geometry/point.py", line 73, in __new__
#     coords = np.array(args).squeeze()
#              ~~~~~~~~^^^^^^
#   File "/tmp/ipykernel_130682/2446021062.py", line 57, in find_polygon
#     if elem["polygon"].contains(Point(row["LONGITUDE"], row["LATITUDE"])):
#        ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/construction.py", line 681, in sanitize_array
#     subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1167, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/series.py", line 515, in __init__
#     data = SingleBlockManager.from_array(data, index, refs=refs)
#   File "/tmp/ipykernel_130682/2446021062.py", line 56, in find_polygon
#     for p_idx, elem in df.iterrows():
#                        ~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/geometry/point.py", line 81, in __new__
#     geom = shapely.points(coords)
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1183, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_130682/2446021062.py", line 57, in find_polygon
#     if elem["polygon"].contains(Point(row["LONGITUDE"], row["LATITUDE"])):
#                                 ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_130682/2446021062.py", line 56, in find_polygon
#     for p_idx, elem in df.iterrows():
#                        ~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/geometry/base.py", line 774, in contains
#     return _maybe_unpack(shapely.contains(self, other))
#                          ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "/tmp/ipykernel_130682/2446021062.py", line 57, in find_polygon
#     if elem["polygon"].contains(Point(row["LONGITUDE"], row["LATITUDE"])):
#        ~~~~^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/construction.py", line 718, in _sanitize_ndim
#     def _sanitize_ndim(
#
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/internals/managers.py", line 2024, in from_array
#     block = new_block(array, placement=bp, ndim=1, refs=refs)
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/decorators.py", line 173, in wrapper
#     result = func(*args, **kwargs)
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 1586, in iterrows
#     s = klass(v, index=columns, name=k).__finalize__(self)
#         ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/apply.py", line 1183, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#         *user_defined_function_args, **user_defined_functions_kwargs
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/geometry/point.py", line 81, in __new__
#     geom = shapely.points(coords)
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/decorators.py", line 88, in wrapped
#     return func(*args, **kwargs)
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 1586, in iterrows
#     s = klass(v, index=columns, name=k).__finalize__(self)
#         ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/series.py", line 959, in __getitem__
#     return self._get_value(key)
#            ~~~~~~~~~~~~~~~^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/decorators.py", line 76, in wrapped
#     arg for arg in args if isinstance(arg, np.ndarray) and arg.dtype == object
#     ^^^
# KeyboardInterrupt
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#         *user_defined_function_args, **user_defined_functions_kwargs
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/series.py", line 514, in __init__
#     data = sanitize_array(data, index, dtype, copy)
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/internals/blocks.py", line 2270, in new_block
#     return klass(values, ndim=ndim, placement=placement, refs=refs)
#   File "/tmp/ipykernel_130682/2446021062.py", line 56, in find_polygon
#     for p_idx, elem in df.iterrows():
#                        ~~~~~~~~~~~^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/decorators.py", line 173, in wrapper
#     result = func(*args, **kwargs)
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/predicates.py", line 608, in contains
#     return lib.contains(a, b, **kwargs)
#            ~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/series.py", line 1049, in _get_value
#     return self._values[loc]
#            ^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/series.py", line 514, in __init__
#     data = sanitize_array(data, index, dtype, copy)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/tmp/ipykernel_130682/2446021062.py", line 57, in find_polygon
#     if elem["polygon"].contains(Point(row["LONGITUDE"], row["LATITUDE"])):
#        ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/construction.py", line 616, in sanitize_array
#     subarr = lib.maybe_convert_objects(
#         data,
#     ...<5 lines>...
#         dtype_if_all_nat=np.dtype("M8[s]"),
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/frame.py", line 1586, in iterrows
#     s = klass(v, index=columns, name=k).__finalize__(self)
#         ~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/decorators.py", line 88, in wrapped
#     return func(*args, **kwargs)
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/series.py", line 789, in _values
#     @property
#
# KeyboardInterrupt
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/construction.py", line 685, in sanitize_array
#     dtype = cast(np.dtype, dtype)
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/geometry/base.py", line 774, in contains
#     return _maybe_unpack(shapely.contains(self, other))
#                          ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "pandas/_libs/lib.pyx", line 2634, in pandas._libs.lib.maybe_convert_objects
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/series.py", line 514, in __init__
#     data = sanitize_array(data, index, dtype, copy)
# KeyboardInterrupt
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/creation.py", line 124, in points
#     return lib.points(coords, np.intc(handle_nan), out=out, **kwargs)
#            ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/typing.py", line 2291, in cast
#     def cast(typ, val):
#
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/shapely/decorators.py", line 76, in wrapped
#     arg for arg in args if isinstance(arg, np.ndarray) and arg.dtype == object
#     ^^^
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandas/core/construction.py", line 616, in sanitize_array
#     subarr = lib.maybe_convert_objects(
#         data,
#     ...<5 lines>...
#         dtype_if_all_nat=np.dtype("M8[s]"),
#     )
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/numpy/_core/numeric.py", line 290, in full
#     @finalize_array_function_like
#
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "pandas/_libs/lib.pyx", line 2634, in pandas._libs.lib.maybe_convert_objects
#   File "/home/lvff/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/numpy/_core/numeric.py", line 290, in full
#     @finalize_array_function_like
#
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 84
#      81 # generate file for each crime
#      82 print("Finding the grid cell for each point...")
#      83 df_final = df_crimes.merge(
# ---> 84     df_crimes.parallel_apply(find_polygon, df=df_poly, axis=1),
#      85     left_index=True,
#      86     right_index=True,
#      87 )
#      89 df_final.to_csv(f"./output/maceio/maceio_with_grid_index.csv", sep=";")
#      90 display(df_final.shape)
#
# File ~/dev/tcc/learning/.pixi/envs/default/lib/python3.14/site-packages/pandarallel/core.py:307, in parallelize_with_memory_file_system.<locals>.closure(data, user_defined_function, *user_defined_function_args, **user_defined_function_kwargs)
#     299 generation = count()
#     301 while any(
#     302     (
#     303         worker_status == WorkerStatus.Running
#     304         for worker_status in workers_status
#     305     )
#     306 ):
# --> 307     message: Tuple[int, WorkerStatus, Any] = master_workers_queue.get()
#     308     worker_index, worker_status, payload = message
#     309     workers_status[worker_index] = worker_status
#
# File <string>:2, in get(self, *args, **kwds)
#
# File ~/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/managers.py:832, in BaseProxy._callmethod(self, methodname, args, kwds)
#     829     conn = self._tls.connection
#     831 conn.send((self._id, methodname, args, kwds))
# --> 832 kind, result = conn.recv()
#     834 if kind == '#RETURN':
#     835     return result
#
# File ~/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/connection.py:256, in _ConnectionBase.recv(self)
#     254 self._check_closed()
#     255 self._check_readable()
# --> 256 buf = self._recv_bytes()
#     257 return _ForkingPickler.loads(buf.getbuffer())
#
# File ~/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/connection.py:447, in Connection._recv_bytes(self, maxsize)
#     446 def _recv_bytes(self, maxsize=None):
# --> 447     buf = self._recv(4)
#     448     size, = struct.unpack("!i", buf.getvalue())
#     449     if size == -1:
#
# File ~/dev/tcc/learning/.pixi/envs/default/lib/python3.14/multiprocessing/connection.py:412, in Connection._recv(self, size, read)
#     410 while remaining > 0:
#     411     to_read = min(BUFSIZE, remaining)
# --> 412     chunk = read(handle, to_read)
#     413     n = len(chunk)
#     414     if n == 0:
#
# KeyboardInterrupt:
