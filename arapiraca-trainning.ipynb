# %% [markdown]
# # Treinamento e avaliação — Arapiraca
#
# Este notebook implementa:
# 1. Definição da arquitetura ConvLSTM (3 camadas, 7 canais ocultos, kernel 3×3)
# 2. Treinamento com BCEWithLogitsLoss e pos_weight para lidar com esparsidade
# 3. Avaliação com métricas tradicionais e com tolerância espacial
# 4. Análise de desempenho por threshold (0,50 a 1,00)
#
# **Entrada:** `arapiraca_chrono.npz`, `arapiraca_mask_final.npy`
#
# **Saída:** Predições, alvos e métricas em `./output/arapiraca/predictions/` e `./output/arapiraca/perf_thrs/`

# %% [markdown]
# ## 1. Definição da arquitetura ConvLSTM
#
# Implementa três classes:
# - **ConvLSTMCell**: Célula individual com portas (input, forget, cell, output) usando convoluções 2D
# - **ConvLSTM**: Empilha múltiplas ConvLSTMCells com BatchNorm e ReLU entre camadas
# - **ConvLSTMModel**: Modelo completo com ConvLSTM + Dropout + Conv2d final para predição binária

# %%
# Arquitetura ConvLSTM
# ConvLSTMCell: implementa as portas da LSTM usando convoluções 2D
# ConvLSTM: empilha N camadas de ConvLSTMCell com normalização
# ConvLSTMModel: modelo final com dropout e convolução de saída

import torch.nn as nn
import torch

class ConvLSTMCell(nn.Module):

    def __init__(self, input_dim, hidden_dim, kernel_size, bias):
        super(ConvLSTMCell, self).__init__()

        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.kernel_size = kernel_size
        self.padding = kernel_size[0] // 2, kernel_size[1] // 2
        self.bias = bias

        self.conv = nn.Conv2d(in_channels=self.input_dim + self.hidden_dim,
                              out_channels=4 * self.hidden_dim,
                              kernel_size=self.kernel_size,
                              padding=self.padding,
                              bias=self.bias)

    def forward(self, input_tensor, cur_state):
        h_cur, c_cur = cur_state

        combined = torch.cat([input_tensor, h_cur], dim=1)  # concatenate along channel axis

        combined_conv = self.conv(combined)
        cc_i, cc_f, cc_o, cc_g = torch.split(combined_conv, self.hidden_dim, dim=1)
        i = torch.sigmoid(cc_i)
        f = torch.sigmoid(cc_f)
        o = torch.sigmoid(cc_o)
        g = torch.tanh(cc_g)

        c_next = f * c_cur + i * g
        h_next = o * torch.tanh(c_next)

        return h_next, c_next

    def init_hidden(self, batch_size, image_size):
        height, width = image_size
        return (torch.zeros(batch_size, self.hidden_dim, height, width, device=self.conv.weight.device),
                torch.zeros(batch_size, self.hidden_dim, height, width, device=self.conv.weight.device))


class ConvLSTM(nn.Module):

    def __init__(self, input_dim, hidden_dim, kernel_size, num_layers, channel_last=True,
                 batch_first=False, bias=True, return_all_layers=False):
        super(ConvLSTM, self).__init__()

        self._check_kernel_size_consistency(kernel_size)

        kernel_size = self._extend_for_multilayer(kernel_size, num_layers)
        hidden_dim = self._extend_for_multilayer(hidden_dim, num_layers)
        if not len(kernel_size) == len(hidden_dim) == num_layers:
            raise ValueError('Inconsistent list length.')

        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.kernel_size = kernel_size
        self.num_layers = num_layers
        self.batch_first = batch_first
        self.channel_last = channel_last
        self.bias = bias
        self.return_all_layers = return_all_layers

        cell_list = []
        bn_list = []
        relu_list = []
        for i in range(0, self.num_layers):
            cur_input_dim = self.input_dim if i == 0 else self.hidden_dim[i - 1]

            cell_list.append(ConvLSTMCell(input_dim=cur_input_dim,
                                          hidden_dim=self.hidden_dim[i],
                                          kernel_size=self.kernel_size[i],
                                          bias=self.bias))
            
            relu_list.append(nn.ReLU())
            bn_list.append(nn.BatchNorm3d(self.hidden_dim[i]))

        self.cell_list = nn.ModuleList(cell_list)
        self.relu_list = nn.ModuleList(relu_list)
        self.bn_list = nn.ModuleList(bn_list)

    def forward(self, input_tensor, hidden_state=None):
        if not self.batch_first:
            input_tensor = input_tensor.permute(1, 0, 2, 3, 4)

        if self.channel_last:
            input_tensor = input_tensor.permute(0, 1, 4, 2, 3)

        b, _, _, h, w = input_tensor.size()

        if hidden_state is not None:
            raise NotImplementedError()
        else:
            hidden_state = self._init_hidden(batch_size=b, image_size=(h, w))

        layer_output_list = []
        last_state_list = []
        seq_len = input_tensor.size(1)
        cur_layer_input = input_tensor

        for layer_idx in range(self.num_layers):
            h, c = hidden_state[layer_idx]
            output_inner = []
            for t in range(seq_len):
                h, c = self.cell_list[layer_idx](input_tensor=cur_layer_input[:, t, :, :, :], cur_state=[h, c])
                output_inner.append(h)

            layer_output = torch.stack(output_inner, dim=1)
            layer_output = self.relu_list[layer_idx](layer_output)
            layer_output = self.bn_list[layer_idx](layer_output)
            #layer_output = layer_output + cur_layer_input  # Apply residual connection
            cur_layer_input = layer_output

            layer_output_list.append(layer_output)
            last_state_list.append([h, c])

        if not self.return_all_layers:
            layer_output_list = layer_output_list[-1:]
            last_state_list = last_state_list[-1:]

        return layer_output_list, last_state_list

    def _init_hidden(self, batch_size, image_size):
        init_states = []
        for i in range(self.num_layers):
            init_states.append(self.cell_list[i].init_hidden(batch_size, image_size))
        return init_states

    @staticmethod
    def _check_kernel_size_consistency(kernel_size):
        if not (isinstance(kernel_size, tuple) or
                (isinstance(kernel_size, list) and all([isinstance(elem, tuple) for elem in kernel_size]))):
            raise ValueError('`kernel_size` must be tuple or list of tuples')

    @staticmethod
    def _extend_for_multilayer(param, num_layers):
        if not isinstance(param, list):
            param = [param] * num_layers
        return param

# %% [markdown]
# ## 2. Treinamento do modelo
#
# Carrega os dados de `arapiraca_chrono.npz`, configura o modelo e executa o loop de treinamento:
# - 200 épocas, batch size 55, Adam com lr=1e-5
# - CosineAnnealingLR como scheduler
# - BCEWithLogitsLoss com pos_weight para compensar o desbalanceamento
# - Salva predições e alvos do conjunto de validação ao final

# %%
# Treinamento do modelo ConvLSTM para Arapiraca
# Carrega dados, configura hiperparâmetros, executa treinamento
# Salva predições e alvos da validação em pickle

import torch
import torch.nn as nn
import torch.optim as optim
from torchsummary import summary
from torchviz import make_dot
from torch.utils.data import DataLoader, TensorDataset, random_split
import torch.nn.functional as F
from torch.nn.functional import one_hot
from torch import Tensor
from typing import Union
from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingLR
from sklearn.metrics import roc_curve
import os

print("Should return True if a GPU is available: ",torch.cuda.is_available())  
print("Number of GPUs available: ",torch.cuda.device_count())  
print("Name of the first GPU: ",torch.cuda.get_device_name(0)) 

from sklearn.utils import class_weight
from sklearn.metrics import mean_squared_error, mean_absolute_error, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
import scipy, scipy.ndimage
import pickle
import sys
import numpy as np
import pandas as pd
# Set the seed for reproducibility
# seed = int(sys.argv[6]) # 42, 0, 123, 999
seed = 42
print("SEED: ", seed)
torch.manual_seed(seed)

# Optionally set the seed for CUDA (if using GPU)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    
# Custom worker_init_fn to ensure each worker has a different seed
def worker_init_fn(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    torch.manual_seed(worker_seed)
    
class PrecisionLoss2(nn.Module):
    def __init__(self, epsilon=1e-8, pos_weight=None):
        super(PrecisionLoss2, self).__init__()
        self.epsilon = epsilon
        self.pos_weight = pos_weight

    def forward(self, logits, targets):
        """
        logits: predicted scores from the model (before applying sigmoid)
        targets: ground truth binary labels (0 or 1)
        """
        # Apply sigmoid to get probabilities
        probs = torch.sigmoid(logits)
        
        if self.pos_weight is not None:
            # Apply class weight to the positive class
            targets = targets * self.pos_weight
        
        # Smooth approximation of true positives
        TP = torch.sum(probs * targets)
        
        # Smooth approximation of false positives
        FP = torch.sum(probs * (1 - targets))
        
        # Precision
        precision = TP / (TP + FP + self.epsilon)
        
        # Loss is defined as 1 - precision (to maximize precision, minimize the loss)
        loss = 1 - precision
        return loss

class FocalLoss2(nn.Module):
    """Computes the focal loss between input and target
    as described here https://arxiv.org/abs/1708.02002v2

    Args:
        gamma (float): The focal loss focusing parameter.
        weights (Union[None, Tensor]): Rescaling weight given to each class.
        If given, has to be a Tensor of size 2 for binary classification. optional.
        reduction (str): Specifies the reduction to apply to the output.
        It should be one of the following 'none', 'mean', or 'sum'.
        default 'mean'.
        ignore_index (int): Specifies a target value that is ignored and
        does not contribute to the input gradient. optional.
        eps (float): Smoothing to prevent log from returning inf.
    """
    def __init__(
            self,
            gamma: float,
            weights: Union[None, Tensor] = None,
            reduction: str = 'mean',
            ignore_index: int = -100,
            eps: float = 1e-16
            ) -> None:
        super().__init__()
        if reduction not in ['mean', 'none', 'sum']:
            raise NotImplementedError(
                'Reduction {} not implemented.'.format(reduction)
                )
        assert weights is None or isinstance(weights, Tensor), \
            'weights should be of type Tensor or None, but {} given'.format(
                type(weights))
        self.reduction = reduction
        self.gamma = gamma
        self.ignore_index = ignore_index
        self.eps = eps
        self.weights = weights

    def forward(self, x: Tensor, target: Tensor) -> Tensor:
        assert torch.all((x >= 0.0) & (x <= 1.0)), ValueError(
            'The prediction values should be between 0 and 1, \
             make sure to pass the values to sigmoid for binary classification'
        )

        # Convert target to float
        target = target.float()

        # Compute the focal loss components
        bce_loss = nn.functional.binary_cross_entropy(x, target, reduction='none')
        pt = torch.where(target == 1, x, 1 - x)  # Probability of the true class
        focal_weight = (1 - pt) ** self.gamma

        # Apply class weights if provided
        if self.weights is not None:
            alpha_t = self.weights[1] * target + self.weights[0] * (1 - target)
            focal_weight = focal_weight * alpha_t

        loss = focal_weight * bce_loss

        # Handle ignore index
        if self.ignore_index >= 0:
            mask = target != self.ignore_index
            loss = loss * mask

        # Reduction
        if self.reduction == 'mean':
            return loss.mean()
        elif self.reduction == 'sum':
            return loss.sum()
        else:
            return loss

def get_neighbours(matrix,indices,distance):
    """
    matrix: numpy array
    indices: list with two integers
    distance: integer bigger than 1
    """
    # get indices of that element in the matrix
    indices = tuple(np.transpose(np.atleast_2d(indices)))
    # create a matrix of ones with same size as the input matrix
    dist = np.ones(np.shape(matrix))
    # put a zero at the location of the element we are looking at
    dist[indices] = 0
    # surround it by increasing numbers 1,2,3...
    dist = scipy.ndimage.distance_transform_cdt(dist, metric='chessboard')
    # get indeces of the values whoes distance is the requested (if we have more than 1, we have to add all previous)
    nb_indices = np.transpose(np.nonzero(dist == 1))
    for i in range(2,distance+1):
        nb_indices = np.concatenate((nb_indices,np.transpose(np.nonzero(dist == i))))
    return [matrix[tuple(ind)] for ind in nb_indices]


def get_custom_conf_matrix(orig,predi,dist=1):
    pred = predi.copy()
    for (i,j), value in np.ndenumerate(orig):
        if orig[i,j]==0 and pred[i,j]==0: # 0: true negative
            continue
        elif orig[i,j]==1 and pred[i,j]==1: # 1: true positive
            continue
        elif orig[i,j]==0 and pred[i,j]==1:
            if 1 in get_neighbours(orig,[i,j],dist):
                pred[i,j]=2 # 2: false positive with neighbouring positive
            else:
                pred[i,j]=3 # 3: false positive without neighbouring positive
        elif orig[i,j]==1 and pred[i,j]==0: # 4: false negative
            pred[i,j]=4

    result = pred.flatten().tolist()

    tn = result.count(0)
    tp = result.count(1)
    fp = result.count(3)
    fn = result.count(4)

    if tp==0 and result.count(2)==0:
        f1_orig = 0
        f1_new = 0
    elif tp==0:
        f1_orig = 0
        f1_new = (tp+result.count(2))/((tp+result.count(2))+0.5*(fp+fn))
    else:
        f1_orig = tp/(tp+0.5*((fp+result.count(2))+fn))
        f1_new = (tp+result.count(2))/((tp+result.count(2))+0.5*(fp+fn))

    if tp+fp+result.count(2) == 0:
        prec = 0
        prec_new = 0
    else:
        prec = tp/(tp+fp+result.count(2))
        prec_new = (tp+result.count(2))/(tp+result.count(2)+fp)
      
    if tp+fn==0:
        rec = 0
    else:  
        rec = tp/(tp+fn)
        
    if tp+result.count(2)+fn == 0:
        rec_new = 0
    else:
        rec_new = (tp+result.count(2))/(tp+result.count(2)+fn)

    return rec,prec,f1_orig,rec_new,prec_new,f1_new,pred

class ConvLSTMModel(nn.Module):
    def __init__(self, num_layers, input_chn, hidden_chn, kernel_size):
        super(ConvLSTMModel, self).__init__()
        self.num_layers = num_layers
    
        self.conv_lstm = ConvLSTM(input_chn, hidden_chn, kernel_size, num_layers, channel_last=True,
                 batch_first=True, bias=True, return_all_layers=True)
        self.final_conv = nn.Conv2d(in_channels=hidden_chn, out_channels=1, kernel_size=(3,3), padding='same')
        self.dropout = nn.Dropout(p=0.8)
    
    def forward(self, x):
        x = self.conv_lstm(x)[1][0][0] # selecting last_output, then extract sublist, then select h
        x = self.dropout(x)
        x = self.final_conv(x)
        return x

def train_model(model, train_loader, val_loader, criterions, optimizer, n_epoch, device, seed):
    criterion, criterion_precision, criterion_focal = criterions
    best_val_loss = +float('inf')
    model.train()
    
    # Define the scheduler
    scheduler = CosineAnnealingLR(optimizer, T_max=20)
    
    for epoch in range(n_epochs):
        running_loss = 0.0
        for data, target in train_loader:
            # move data to the GPU
            data, target = data.to(device), target.to(device)
            
            # zero the parameter gradients
            optimizer.zero_grad()
            
            # forward pass
            output = model(data)
            output = torch.squeeze(output, 1) # make size match
            loss = criterion(output, target)
            
            # backward pass and optimize
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
        
        avg_train_loss = running_loss / len(train_loader)
        avg_val_loss, avg_rec, avg_prec, avg_f1, avg_rec_new, avg_prec_new, avg_f1_new = evaluate_model(model, val_loader, criterions, device, seed)
        
        print(f"Epoch {epoch}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")
            
def evaluate_model(model, val_loader, criterions, device, seed):
    criterion, criterion_precision, criterion_focal = criterions
    model.eval()
    val_loss = 0.0
    all_targets = []
    all_predictions = []
    
    with torch.no_grad():
        for data, target in val_loader:
            
            data, target = data.to(device), target.to(device)
            
            output = model(data)
            output = torch.squeeze(output, 1) # make size match
            loss = criterion(output,target) 
            val_loss += loss.item()
            
            # Collecting predictions and targets for metric calculations
            all_targets.append(target.cpu().numpy())
            all_predictions.append(output.cpu().numpy())
    
    avg_val_loss = val_loss / len(val_loader)
    
    # Concatenate all predictions and targets
    all_targets = np.concatenate(all_targets)
    all_predictions = np.concatenate(all_predictions)
    
    # put model output logits into probabilities
    all_predictions = torch.sigmoid(torch.from_numpy(all_predictions)).numpy()

    # save prediction and truth before applying threshold
    os.makedirs("./output/arapiraca/predictions/", exist_ok=True)
    with open(f"./output/arapiraca/predictions/convlstm_predictions_arapiraca_{seed}.pkl", "wb") as f_p:  
        pickle.dump(all_predictions, f_p)
    with open(f"./output/arapiraca/predictions/convlstm_targets_arapiraca_{seed}.pkl", "wb") as f_t:  
        pickle.dump(all_targets, f_t)
    print("Saved final predictions and targets!")
    
    # apply thr to go from probability to class number
    thr=0.5
    all_predictions[all_predictions >= thr] = 1
    all_predictions[all_predictions < thr] = 0
    
    # Initialize lists to store metrics for each sample
    f1_list = []
    f1_new_list = []
    rec_list = []
    prec_list = []
    rec_new_list = []
    prec_new_list = []
    prec_auto = []
    rec_auto = []
    # Loop over each sample
    for i in range(np.shape(all_predictions)[0]):
        pred_flat = all_predictions[i,:] 
        true_flat = all_targets[i,:] 
        
        rec,prec,f1,rec_new,prec_new,f1_new,pred = get_custom_conf_matrix(true_flat,pred_flat,dist=1)
     
        rec_list.append(rec)
        prec_list.append(prec)
        f1_list.append(f1)
        rec_new_list.append(rec_new)
        prec_new_list.append(prec_new)
        f1_new_list.append(f1_new)
    
    # Compute the average precision, recall, and f1 score across all samples and classes
    avg_prec = np.mean(prec_list)
    avg_rec = np.mean(rec_list)
    avg_f1 = np.mean(f1_list)
    avg_prec_new = np.mean(prec_new)
    avg_rec_new = np.mean(rec_new)
    avg_f1_new = np.mean(f1_new)

    return avg_val_loss, avg_rec, avg_prec, avg_f1, avg_rec_new, avg_prec_new, avg_f1_new


def concat_all_cities(data_name,input_folder,ref_city,cities_list,crime_agg):
    x1 = np.load(f'./output/arapiraca/arapiraca_chrono.npz')[data_name]
    return x1

def select_features(x_train,x_val):
    # keep only C channel
    x_train = x_train[:,:,:,:,0]
    x_val = x_val[:,:,:,:,0]
    x_train = np.expand_dims(x_train, axis=-1)
    x_val = np.expand_dims(x_val, axis=-1)
    return (torch.from_numpy(x_train),torch.from_numpy(x_val))


def main(batch_size, n_epochs, input_folder, ref_city, cities_list, crime_agg, num_layers, input_chn, hidden_chn, kernel_size, seed):
    # load the data as tensors
    x_train = torch.from_numpy(concat_all_cities(data_name='x_train',input_folder=input_folder,ref_city=ref_city,cities_list=cities_list,crime_agg=crime_agg)).float() 
    y_train = torch.from_numpy(concat_all_cities(data_name='y_train',input_folder=input_folder,ref_city=ref_city,cities_list=cities_list,crime_agg=crime_agg)).float()
    i_train = concat_all_cities(data_name='i_train',input_folder=input_folder,ref_city=ref_city,cities_list=cities_list,crime_agg=crime_agg)
    x_val = torch.from_numpy(concat_all_cities(data_name='x_val',input_folder=input_folder,ref_city=ref_city,cities_list=cities_list,crime_agg=crime_agg)).float()
    y_val = torch.from_numpy(concat_all_cities(data_name='y_val',input_folder=input_folder,ref_city=ref_city,cities_list=cities_list,crime_agg=crime_agg)).float()
    i_val = concat_all_cities(data_name='i_val',input_folder=input_folder,ref_city=ref_city,cities_list=cities_list,crime_agg=crime_agg)
    
    # Shuffle training data
    train_indices = np.random.permutation(x_train.shape[0])
    x_train = x_train[train_indices]
    y_train = y_train[train_indices]
    i_train = i_train[train_indices]

    # Shuffle validation data
    val_indices = np.random.permutation(x_val.shape[0])
    x_val = x_val[val_indices]
    y_val = y_val[val_indices]
    i_val = i_val[val_indices]
    
    # truncate to largest multiple of batch_size for consistent batching
    n_train = (x_train.shape[0] // batch_size) * batch_size
    n_val = (x_val.shape[0] // batch_size) * batch_size
    x_train = x_train[:n_train]
    y_train = y_train[:n_train]
    i_train = i_train[:n_train]
    x_val = x_val[:n_val]
    y_val = y_val[:n_val]
    i_val = i_val[:n_val]
    
    # Setting all NaN values to 0 (since they have been correctly identified already)
    x_train[torch.isnan(x_train)] = 0
    y_train[torch.isnan(y_train)] = 0
    x_val[torch.isnan(x_val)] = 0
    y_val[torch.isnan(y_val)] = 0
    
    # keep only the C (crime) channel
    x_train, x_val = select_features(x_train=x_train,x_val=x_val)
    
    print(f"Shapes: {np.shape(x_train)} {np.shape(y_train)}")
    print(f"Shapes: {np.shape(x_val)} {np.shape(y_val)}")
    
    # remove channel dimension so it will work at the end
    y_train = y_train.permute(0, 3, 1, 2)
    y_val = y_val.permute(0, 3, 1, 2)
    y_train = torch.squeeze(y_train, 1)
    y_val = torch.squeeze(y_val, 1)
    
    # define the device
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # data loaders
    train_loader = DataLoader(TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True,worker_init_fn=worker_init_fn)
    test_loader = DataLoader(TensorDataset(x_val, y_val), batch_size=batch_size, shuffle=False)

    # Model
    model = ConvLSTMModel(num_layers, input_chn, hidden_chn, kernel_size)
    print(model)
    total_params = sum(p.numel() for p in model.parameters())
    print(f'Total number of parameters: {total_params}')  
    model.to(device) # to work on GPU
    
    # Calculate class weights
    targets_flat = y_train.view(-1)  # Flatten targets to (n_samples * 22 * 22)

    # Calculate the number of positive and negative examples
    num_positives = targets_flat.sum().item()
    num_negatives = targets_flat.size(0) - num_positives

    pos_weight = num_negatives / num_positives # Calculate pos_weight for the positive class

    # Convert pos_weight to a PyTorch tensor
    pos_weight_tensor = torch.tensor(pos_weight).float().to(device) # targets.device
    print("pos_weight_tensor: ",pos_weight_tensor)
    print([1, pos_weight_tensor.cpu().item()])
    
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight_tensor) 
    criterion_precision = PrecisionLoss2(pos_weight=pos_weight_tensor)
    criterion_focal = FocalLoss2(gamma=6,weights=torch.tensor([1, pos_weight_tensor.cpu().item()])) 
    criterions = (criterion, criterion_precision, criterion_focal)
    optimizer = optim.Adam(model.parameters(), lr=0.00001) 
    
    print("Training model...") 
    train_model(model, train_loader, test_loader, criterions, optimizer, n_epochs, device, seed)

    # make output folder if it does not exist
    os.makedirs("predictions", exist_ok=True)

    # save index of subgrids used
    with open(f"./output/arapiraca/predictions/convlstm_i_arapiraca__{seed}.pkl", "wb") as f:  
        pickle.dump(i_val, f)
    
if __name__ == "__main__":
    
    # params data loading
    input_folder = "./output/maceio"
    ref_city = "arapiraca"
    cities_list = None
    crime_agg = "all"
    seq_length = 8
    
    # params architecture model
    num_layers = 3
    hidden_chn = seq_length-1 #needs to match sequence legth (so LB-1)
    kernel_size = (3,3)

    input_chn = 1

    # params training
    batch_size = 55
    n_epochs = 200

    print(f"Data settings: ref_city={ref_city}, cities_list={cities_list}, crime_agg={crime_agg}")
    print(f"Settings: n_epochs={n_epochs}, batch_size={batch_size}, num_layers={num_layers}, hidden_chn={hidden_chn}")
    main(batch_size, n_epochs, input_folder, ref_city, cities_list, crime_agg, num_layers, input_chn, hidden_chn, kernel_size, seed)
# Out:
# Should return True if a GPU is available:  True
# Number of GPUs available:  1
# Name of the first GPU:  NVIDIA GeForce RTX 4070 Laptop GPU
# SEED:  42
# Data settings: ref_city=arapiraca, cities_list=None, crime_agg=all
# Settings: n_epochs=200, batch_size=55, num_layers=3, hidden_chn=7
# Shapes: torch.Size([17160, 7, 16, 16, 1]) torch.Size([17160, 16, 16, 1])
# Shapes: torch.Size([1650, 7, 16, 16, 1]) torch.Size([1650, 16, 16, 1])
# ConvLSTMModel(
#   (conv_lstm): ConvLSTM(
#     (cell_list): ModuleList(
#       (0): ConvLSTMCell(
#         (conv): Conv2d(8, 28, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1-2): 2 x ConvLSTMCell(
#         (conv): Conv2d(14, 28, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (relu_list): ModuleList(
#       (0-2): 3 x ReLU()
#     )
#     (bn_list): ModuleList(
#       (0-2): 3 x BatchNorm3d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (final_conv): Conv2d(7, 1, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (dropout): Dropout(p=0.8, inplace=False)
# )
# Total number of parameters: 9262
# pos_weight_tensor:  tensor(127.0560, device='cuda:0')
# [1, 127.05596923828125]
# Training model...
# Saved final predictions and targets!
# Epoch 0, Train Loss: 1.3761, Val Loss: 1.2258
# Saved final predictions and targets!
# Epoch 1, Train Loss: 1.3751, Val Loss: 1.2258
# Saved final predictions and targets!
# Epoch 2, Train Loss: 1.3746, Val Loss: 1.2258
# Saved final predictions and targets!
# Epoch 3, Train Loss: 1.3740, Val Loss: 1.2258
# Saved final predictions and targets!
# Epoch 4, Train Loss: 1.3733, Val Loss: 1.2256
# Saved final predictions and targets!
# Epoch 5, Train Loss: 1.3723, Val Loss: 1.2254
# Saved final predictions and targets!
# Epoch 6, Train Loss: 1.3711, Val Loss: 1.2249
# Saved final predictions and targets!
# Epoch 7, Train Loss: 1.3693, Val Loss: 1.2242
# Saved final predictions and targets!
# Epoch 8, Train Loss: 1.3667, Val Loss: 1.2228
# Saved final predictions and targets!
# Epoch 9, Train Loss: 1.3628, Val Loss: 1.2207
# Saved final predictions and targets!
# Epoch 10, Train Loss: 1.3566, Val Loss: 1.2171
# Saved final predictions and targets!
# Epoch 11, Train Loss: 1.3466, Val Loss: 1.2109
# Saved final predictions and targets!
# Epoch 12, Train Loss: 1.3307, Val Loss: 1.2010
# Saved final predictions and targets!
# Epoch 13, Train Loss: 1.3059, Val Loss: 1.1849
# Saved final predictions and targets!
# Epoch 14, Train Loss: 1.2709, Val Loss: 1.1620
# Saved final predictions and targets!
# Epoch 15, Train Loss: 1.2288, Val Loss: 1.1362
# Saved final predictions and targets!
# Epoch 16, Train Loss: 1.1877, Val Loss: 1.1131
# Saved final predictions and targets!
# Epoch 17, Train Loss: 1.1561, Val Loss: 1.0977
# Saved final predictions and targets!
# Epoch 18, Train Loss: 1.1370, Val Loss: 1.0904
# Saved final predictions and targets!
# Epoch 19, Train Loss: 1.1273, Val Loss: 1.0873
# Saved final predictions and targets!
# Epoch 20, Train Loss: 1.1226, Val Loss: 1.0876
# Saved final predictions and targets!
# Epoch 21, Train Loss: 1.1202, Val Loss: 1.0865
# Saved final predictions and targets!
# Epoch 22, Train Loss: 1.1186, Val Loss: 1.0865
# Saved final predictions and targets!
# Epoch 23, Train Loss: 1.1173, Val Loss: 1.0844
# Saved final predictions and targets!
# Epoch 24, Train Loss: 1.1162, Val Loss: 1.0846
# Saved final predictions and targets!
# Epoch 25, Train Loss: 1.1151, Val Loss: 1.0820
# Saved final predictions and targets!
# Epoch 26, Train Loss: 1.1141, Val Loss: 1.0841
# Saved final predictions and targets!
# Epoch 27, Train Loss: 1.1132, Val Loss: 1.0814
# Saved final predictions and targets!
# Epoch 28, Train Loss: 1.1123, Val Loss: 1.0813
# Saved final predictions and targets!
# Epoch 29, Train Loss: 1.1113, Val Loss: 1.0805
# Saved final predictions and targets!
# Epoch 30, Train Loss: 1.1105, Val Loss: 1.0817
# Saved final predictions and targets!
# Epoch 31, Train Loss: 1.1097, Val Loss: 1.0807
# Saved final predictions and targets!
# Epoch 32, Train Loss: 1.1090, Val Loss: 1.0808
# Saved final predictions and targets!
# Epoch 33, Train Loss: 1.1083, Val Loss: 1.0778
# Saved final predictions and targets!
# Epoch 34, Train Loss: 1.1076, Val Loss: 1.0795
# Saved final predictions and targets!
# Epoch 35, Train Loss: 1.1070, Val Loss: 1.0784
# Saved final predictions and targets!
# Epoch 36, Train Loss: 1.1064, Val Loss: 1.0774
# Saved final predictions and targets!
# Epoch 37, Train Loss: 1.1058, Val Loss: 1.0781
# Saved final predictions and targets!
# Epoch 38, Train Loss: 1.1052, Val Loss: 1.0770
# Saved final predictions and targets!
# Epoch 39, Train Loss: 1.1047, Val Loss: 1.0768
# Saved final predictions and targets!
# Epoch 40, Train Loss: 1.1042, Val Loss: 1.0763
# Saved final predictions and targets!
# Epoch 41, Train Loss: 1.1037, Val Loss: 1.0755
# Saved final predictions and targets!
# Epoch 42, Train Loss: 1.1032, Val Loss: 1.0754
# Saved final predictions and targets!
# Epoch 43, Train Loss: 1.1028, Val Loss: 1.0748
# Saved final predictions and targets!
# Epoch 44, Train Loss: 1.1023, Val Loss: 1.0761
# Saved final predictions and targets!
# Epoch 45, Train Loss: 1.1019, Val Loss: 1.0775
# Saved final predictions and targets!
# Epoch 46, Train Loss: 1.1015, Val Loss: 1.0750
# Saved final predictions and targets!
# Epoch 47, Train Loss: 1.1010, Val Loss: 1.0742
# Saved final predictions and targets!
# Epoch 48, Train Loss: 1.1005, Val Loss: 1.0747
# Saved final predictions and targets!
# Epoch 49, Train Loss: 1.1002, Val Loss: 1.0742
# Saved final predictions and targets!
# Epoch 50, Train Loss: 1.0997, Val Loss: 1.0741
# Saved final predictions and targets!
# Epoch 51, Train Loss: 1.0994, Val Loss: 1.0740
# Saved final predictions and targets!
# Epoch 52, Train Loss: 1.0989, Val Loss: 1.0717
# Saved final predictions and targets!
# Epoch 53, Train Loss: 1.0986, Val Loss: 1.0725
# Saved final predictions and targets!
# Epoch 54, Train Loss: 1.0982, Val Loss: 1.0742
# Saved final predictions and targets!
# Epoch 55, Train Loss: 1.0977, Val Loss: 1.0719
# Saved final predictions and targets!
# Epoch 56, Train Loss: 1.0973, Val Loss: 1.0726
# Saved final predictions and targets!
# Epoch 57, Train Loss: 1.0970, Val Loss: 1.0715
# Saved final predictions and targets!
# Epoch 58, Train Loss: 1.0966, Val Loss: 1.0707
# Saved final predictions and targets!
# Epoch 59, Train Loss: 1.0963, Val Loss: 1.0704
# Saved final predictions and targets!
# Epoch 60, Train Loss: 1.0959, Val Loss: 1.0725
# Saved final predictions and targets!
# Epoch 61, Train Loss: 1.0955, Val Loss: 1.0704
# Saved final predictions and targets!
# Epoch 62, Train Loss: 1.0952, Val Loss: 1.0691
# Saved final predictions and targets!
# Epoch 63, Train Loss: 1.0948, Val Loss: 1.0731
# Saved final predictions and targets!
# Epoch 64, Train Loss: 1.0945, Val Loss: 1.0704
# Saved final predictions and targets!
# Epoch 65, Train Loss: 1.0941, Val Loss: 1.0708
# Saved final predictions and targets!
# Epoch 66, Train Loss: 1.0938, Val Loss: 1.0696
# Saved final predictions and targets!
# Epoch 67, Train Loss: 1.0935, Val Loss: 1.0692
# Saved final predictions and targets!
# Epoch 68, Train Loss: 1.0931, Val Loss: 1.0687
# Saved final predictions and targets!
# Epoch 69, Train Loss: 1.0927, Val Loss: 1.0678
# Saved final predictions and targets!
# Epoch 70, Train Loss: 1.0924, Val Loss: 1.0683
# Saved final predictions and targets!
# Epoch 71, Train Loss: 1.0921, Val Loss: 1.0671
# Saved final predictions and targets!
# Epoch 72, Train Loss: 1.0918, Val Loss: 1.0679
# Saved final predictions and targets!
# Epoch 73, Train Loss: 1.0914, Val Loss: 1.0675
# Saved final predictions and targets!
# Epoch 74, Train Loss: 1.0911, Val Loss: 1.0659
# Saved final predictions and targets!
# Epoch 75, Train Loss: 1.0909, Val Loss: 1.0673
# Saved final predictions and targets!
# Epoch 76, Train Loss: 1.0905, Val Loss: 1.0676
# Saved final predictions and targets!
# Epoch 77, Train Loss: 1.0902, Val Loss: 1.0670
# Saved final predictions and targets!
# Epoch 78, Train Loss: 1.0899, Val Loss: 1.0657
# Saved final predictions and targets!
# Epoch 79, Train Loss: 1.0895, Val Loss: 1.0650
# Saved final predictions and targets!
# Epoch 80, Train Loss: 1.0892, Val Loss: 1.0651
# Saved final predictions and targets!
# Epoch 81, Train Loss: 1.0889, Val Loss: 1.0667
# Saved final predictions and targets!
# Epoch 82, Train Loss: 1.0886, Val Loss: 1.0662
# Saved final predictions and targets!
# Epoch 83, Train Loss: 1.0883, Val Loss: 1.0632
# Saved final predictions and targets!
# Epoch 84, Train Loss: 1.0880, Val Loss: 1.0641
# Saved final predictions and targets!
# Epoch 85, Train Loss: 1.0877, Val Loss: 1.0647
# Saved final predictions and targets!
# Epoch 86, Train Loss: 1.0874, Val Loss: 1.0651
# Saved final predictions and targets!
# Epoch 87, Train Loss: 1.0871, Val Loss: 1.0633
# Saved final predictions and targets!
# Epoch 88, Train Loss: 1.0868, Val Loss: 1.0635
# Saved final predictions and targets!
# Epoch 89, Train Loss: 1.0865, Val Loss: 1.0631
# Saved final predictions and targets!
# Epoch 90, Train Loss: 1.0862, Val Loss: 1.0633
# Saved final predictions and targets!
# Epoch 91, Train Loss: 1.0859, Val Loss: 1.0627
# Saved final predictions and targets!
# Epoch 92, Train Loss: 1.0857, Val Loss: 1.0622
# Saved final predictions and targets!
# Epoch 93, Train Loss: 1.0853, Val Loss: 1.0626
# Saved final predictions and targets!
# Epoch 94, Train Loss: 1.0850, Val Loss: 1.0628
# Saved final predictions and targets!
# Epoch 95, Train Loss: 1.0848, Val Loss: 1.0611
# Saved final predictions and targets!
# Epoch 96, Train Loss: 1.0845, Val Loss: 1.0635
# Saved final predictions and targets!
# Epoch 97, Train Loss: 1.0842, Val Loss: 1.0614
# Saved final predictions and targets!
# Epoch 98, Train Loss: 1.0839, Val Loss: 1.0619
# Saved final predictions and targets!
# Epoch 99, Train Loss: 1.0837, Val Loss: 1.0611
# Saved final predictions and targets!
# Epoch 100, Train Loss: 1.0834, Val Loss: 1.0593
# Saved final predictions and targets!
# Epoch 101, Train Loss: 1.0831, Val Loss: 1.0604
# Saved final predictions and targets!
# Epoch 102, Train Loss: 1.0828, Val Loss: 1.0607
# Saved final predictions and targets!
# Epoch 103, Train Loss: 1.0826, Val Loss: 1.0618
# Saved final predictions and targets!
# Epoch 104, Train Loss: 1.0823, Val Loss: 1.0610
# Saved final predictions and targets!
# Epoch 105, Train Loss: 1.0821, Val Loss: 1.0609
# Saved final predictions and targets!
# Epoch 106, Train Loss: 1.0818, Val Loss: 1.0591
# Saved final predictions and targets!
# Epoch 107, Train Loss: 1.0815, Val Loss: 1.0603
# Saved final predictions and targets!
# Epoch 108, Train Loss: 1.0813, Val Loss: 1.0595
# Saved final predictions and targets!
# Epoch 109, Train Loss: 1.0810, Val Loss: 1.0585
# Saved final predictions and targets!
# Epoch 110, Train Loss: 1.0807, Val Loss: 1.0592
# Saved final predictions and targets!
# Epoch 111, Train Loss: 1.0805, Val Loss: 1.0584
# Saved final predictions and targets!
# Epoch 112, Train Loss: 1.0802, Val Loss: 1.0596
# Saved final predictions and targets!
# Epoch 113, Train Loss: 1.0800, Val Loss: 1.0584
# Saved final predictions and targets!
# Epoch 114, Train Loss: 1.0797, Val Loss: 1.0558
# Saved final predictions and targets!
# Epoch 115, Train Loss: 1.0795, Val Loss: 1.0601
# Saved final predictions and targets!
# Epoch 116, Train Loss: 1.0793, Val Loss: 1.0584
# Saved final predictions and targets!
# Epoch 117, Train Loss: 1.0790, Val Loss: 1.0573
# Saved final predictions and targets!
# Epoch 118, Train Loss: 1.0788, Val Loss: 1.0571
# Saved final predictions and targets!
# Epoch 119, Train Loss: 1.0785, Val Loss: 1.0573
# Saved final predictions and targets!
# Epoch 120, Train Loss: 1.0783, Val Loss: 1.0576
# Saved final predictions and targets!
# Epoch 121, Train Loss: 1.0781, Val Loss: 1.0555
# Saved final predictions and targets!
# Epoch 122, Train Loss: 1.0779, Val Loss: 1.0567
# Saved final predictions and targets!
# Epoch 123, Train Loss: 1.0776, Val Loss: 1.0558
# Saved final predictions and targets!
# Epoch 124, Train Loss: 1.0774, Val Loss: 1.0559
# Saved final predictions and targets!
# Epoch 125, Train Loss: 1.0772, Val Loss: 1.0564
# Saved final predictions and targets!
# Epoch 126, Train Loss: 1.0769, Val Loss: 1.0544
# Saved final predictions and targets!
# Epoch 127, Train Loss: 1.0767, Val Loss: 1.0580
# Saved final predictions and targets!
# Epoch 128, Train Loss: 1.0765, Val Loss: 1.0554
# Saved final predictions and targets!
# Epoch 129, Train Loss: 1.0763, Val Loss: 1.0550
# Saved final predictions and targets!
# Epoch 130, Train Loss: 1.0761, Val Loss: 1.0550
# Saved final predictions and targets!
# Epoch 131, Train Loss: 1.0759, Val Loss: 1.0537
# Saved final predictions and targets!
# Epoch 132, Train Loss: 1.0756, Val Loss: 1.0542
# Saved final predictions and targets!
# Epoch 133, Train Loss: 1.0754, Val Loss: 1.0547
# Saved final predictions and targets!
# Epoch 134, Train Loss: 1.0753, Val Loss: 1.0529
# Saved final predictions and targets!
# Epoch 135, Train Loss: 1.0750, Val Loss: 1.0556
# Saved final predictions and targets!
# Epoch 136, Train Loss: 1.0748, Val Loss: 1.0520
# Saved final predictions and targets!
# Epoch 137, Train Loss: 1.0746, Val Loss: 1.0542
# Saved final predictions and targets!
# Epoch 138, Train Loss: 1.0744, Val Loss: 1.0536
# Saved final predictions and targets!
# Epoch 139, Train Loss: 1.0743, Val Loss: 1.0535
# Saved final predictions and targets!
# Epoch 140, Train Loss: 1.0740, Val Loss: 1.0510
# Saved final predictions and targets!
# Epoch 141, Train Loss: 1.0739, Val Loss: 1.0540
# Saved final predictions and targets!
# Epoch 142, Train Loss: 1.0737, Val Loss: 1.0512
# Saved final predictions and targets!
# Epoch 143, Train Loss: 1.0735, Val Loss: 1.0524
# Saved final predictions and targets!
# Epoch 144, Train Loss: 1.0733, Val Loss: 1.0532
# Saved final predictions and targets!
# Epoch 145, Train Loss: 1.0731, Val Loss: 1.0525
# Saved final predictions and targets!
# Epoch 146, Train Loss: 1.0729, Val Loss: 1.0528
# Saved final predictions and targets!
# Epoch 147, Train Loss: 1.0728, Val Loss: 1.0508
# Saved final predictions and targets!
# Epoch 148, Train Loss: 1.0726, Val Loss: 1.0507
# Saved final predictions and targets!
# Epoch 149, Train Loss: 1.0724, Val Loss: 1.0517
# Saved final predictions and targets!
# Epoch 150, Train Loss: 1.0722, Val Loss: 1.0499
# Saved final predictions and targets!
# Epoch 151, Train Loss: 1.0720, Val Loss: 1.0521
# Saved final predictions and targets!
# Epoch 152, Train Loss: 1.0719, Val Loss: 1.0513
# Saved final predictions and targets!
# Epoch 153, Train Loss: 1.0717, Val Loss: 1.0501
# Saved final predictions and targets!
# Epoch 154, Train Loss: 1.0715, Val Loss: 1.0514
# Saved final predictions and targets!
# Epoch 155, Train Loss: 1.0714, Val Loss: 1.0518
# Saved final predictions and targets!
# Epoch 156, Train Loss: 1.0712, Val Loss: 1.0496
# Saved final predictions and targets!
# Epoch 157, Train Loss: 1.0710, Val Loss: 1.0506
# Saved final predictions and targets!
# Epoch 158, Train Loss: 1.0708, Val Loss: 1.0530
# Saved final predictions and targets!
# Epoch 159, Train Loss: 1.0707, Val Loss: 1.0487
# Saved final predictions and targets!
# Epoch 160, Train Loss: 1.0705, Val Loss: 1.0504
# Saved final predictions and targets!
# Epoch 161, Train Loss: 1.0704, Val Loss: 1.0502
# Saved final predictions and targets!
# Epoch 162, Train Loss: 1.0703, Val Loss: 1.0492
# Saved final predictions and targets!
# Epoch 163, Train Loss: 1.0700, Val Loss: 1.0495
# Saved final predictions and targets!
# Epoch 164, Train Loss: 1.0699, Val Loss: 1.0487
# Saved final predictions and targets!
# Epoch 165, Train Loss: 1.0698, Val Loss: 1.0493
# Saved final predictions and targets!
# Epoch 166, Train Loss: 1.0696, Val Loss: 1.0467
# Saved final predictions and targets!
# Epoch 167, Train Loss: 1.0695, Val Loss: 1.0482
# Saved final predictions and targets!
# Epoch 168, Train Loss: 1.0693, Val Loss: 1.0479
# Saved final predictions and targets!
# Epoch 169, Train Loss: 1.0692, Val Loss: 1.0489
# Saved final predictions and targets!
# Epoch 170, Train Loss: 1.0690, Val Loss: 1.0485
# Saved final predictions and targets!
# Epoch 171, Train Loss: 1.0689, Val Loss: 1.0488
# Saved final predictions and targets!
# Epoch 172, Train Loss: 1.0688, Val Loss: 1.0472
# Saved final predictions and targets!
# Epoch 173, Train Loss: 1.0687, Val Loss: 1.0482
# Saved final predictions and targets!
# Epoch 174, Train Loss: 1.0685, Val Loss: 1.0455
# Saved final predictions and targets!
# Epoch 175, Train Loss: 1.0684, Val Loss: 1.0485
# Saved final predictions and targets!
# Epoch 176, Train Loss: 1.0682, Val Loss: 1.0494
# Saved final predictions and targets!
# Epoch 177, Train Loss: 1.0681, Val Loss: 1.0487
# Saved final predictions and targets!
# Epoch 178, Train Loss: 1.0680, Val Loss: 1.0473
# Saved final predictions and targets!
# Epoch 179, Train Loss: 1.0679, Val Loss: 1.0476
# Saved final predictions and targets!
# Epoch 180, Train Loss: 1.0678, Val Loss: 1.0467
# Saved final predictions and targets!
# Epoch 181, Train Loss: 1.0676, Val Loss: 1.0456
# Saved final predictions and targets!
# Epoch 182, Train Loss: 1.0675, Val Loss: 1.0465
# Saved final predictions and targets!
# Epoch 183, Train Loss: 1.0674, Val Loss: 1.0460
# Saved final predictions and targets!
# Epoch 184, Train Loss: 1.0673, Val Loss: 1.0464
# Saved final predictions and targets!
# Epoch 185, Train Loss: 1.0672, Val Loss: 1.0459
# Saved final predictions and targets!
# Epoch 186, Train Loss: 1.0671, Val Loss: 1.0460
# Saved final predictions and targets!
# Epoch 187, Train Loss: 1.0670, Val Loss: 1.0458
# Saved final predictions and targets!
# Epoch 188, Train Loss: 1.0668, Val Loss: 1.0480
# Saved final predictions and targets!
# Epoch 189, Train Loss: 1.0668, Val Loss: 1.0455
# Saved final predictions and targets!
# Epoch 190, Train Loss: 1.0666, Val Loss: 1.0478
# Saved final predictions and targets!
# Epoch 191, Train Loss: 1.0666, Val Loss: 1.0451
# Saved final predictions and targets!
# Epoch 192, Train Loss: 1.0665, Val Loss: 1.0464
# Saved final predictions and targets!
# Epoch 193, Train Loss: 1.0663, Val Loss: 1.0465
# Saved final predictions and targets!
# Epoch 194, Train Loss: 1.0663, Val Loss: 1.0451
# Saved final predictions and targets!
# Epoch 195, Train Loss: 1.0661, Val Loss: 1.0470
# Saved final predictions and targets!
# Epoch 196, Train Loss: 1.0661, Val Loss: 1.0444
# Saved final predictions and targets!
# Epoch 197, Train Loss: 1.0660, Val Loss: 1.0464
# Saved final predictions and targets!
# Epoch 198, Train Loss: 1.0659, Val Loss: 1.0441
# Saved final predictions and targets!
# Epoch 199, Train Loss: 1.0658, Val Loss: 1.0461

# %% [markdown]
# ## 3. Avaliação por threshold
#
# Calcula métricas de desempenho para 51 thresholds (0,50 a 1,00):
# - **Métricas tradicionais**: recall, precision, F1 (célula exata)
# - **Métricas com tolerância espacial**: considera acerto se o crime real está em uma célula vizinha (distância de Chebyshev ≤ 1)
#
# A máscara de validade é aplicada para ignorar células fora do município.

# %%
# Avaliação por threshold com métricas tradicionais e espaciais
# get_custom_conf_matrix(): calcula TP, FP, FN com e sem tolerância espacial
# Varre thresholds de 0.50 a 1.00 em passos de 0.01
# Salva resultados em pickle para análise posterior

import numpy as np
import pickle
import sys
from sklearn.metrics import confusion_matrix
import scipy.ndimage
import os

def get_neighbours(matrix, indices, distance, mask=None):
    """
    matrix: numpy array
    indices: list with two integers
    distance: integer >= 1
    mask: optional mask (1 = valid, 0 = invalid)
    """
    indices = tuple(np.transpose(np.atleast_2d(indices)))
    dist = np.ones(np.shape(matrix))
    dist[indices] = 0

    dist = scipy.ndimage.distance_transform_cdt(dist, metric='chessboard')
    nb_indices = np.transpose(np.nonzero(dist == 1))
    for i in range(2, distance + 1):
        nb_indices = np.concatenate((nb_indices, np.transpose(np.nonzero(dist == i))))

    neighbours = []
    for ind in nb_indices:
        i, j = ind
        if 0 <= i < matrix.shape[0] and 0 <= j < matrix.shape[1]:
            if mask is None or mask[i, j] == 1:  # only use valid cells
                neighbours.append(matrix[i, j])
    return neighbours


def get_custom_conf_matrix(orig, predi, dist=1, mask=None):
    pred = predi.copy()
    for (i, j), value in np.ndenumerate(orig):
        if mask is not None and mask[i, j] == 0:
            continue  # skip masked cells 
        if orig[i, j] == 0 and pred[i, j] == 0:  # TN
            continue
        elif orig[i, j] == 1 and pred[i, j] == 1:  # TP
            continue
        elif orig[i, j] == 0 and pred[i, j] == 1:
            if 1 in get_neighbours(orig, [i, j], dist, mask=mask):
                pred[i, j] = 2  # FP with neighboring crime
            else:
                pred[i, j] = 3  # FP with no neighbor
        elif orig[i, j] == 1 and pred[i, j] == 0:  # FN
            pred[i, j] = 4

    result = pred[mask == 1].flatten().tolist() if mask is not None else pred.flatten().tolist()
    
    tn = result.count(0)
    tp = result.count(1)
    fp = result.count(3)
    fn = result.count(4)
    fp_nb = result.count(2)

    # F1 & Precision/Recall handling
    if tp == 0 and fp_nb == 0:
        f1_orig = f1_new = 0
    elif tp == 0:
        f1_orig = 0
        f1_new = (tp + fp_nb) / ((tp + fp_nb) + 0.5 * (fp + fn))
    else:
        f1_orig = tp / (tp + 0.5 * ((fp + fp_nb) + fn))
        f1_new = (tp + fp_nb) / ((tp + fp_nb) + 0.5 * (fp + fn))

    if tp + fp + fp_nb == 0:
        prec = prec_new = 0
    else:
        prec = tp / (tp + fp + fp_nb)
        prec_new = (tp + fp_nb) / (tp + fp_nb + fp)

    rec = tp / (tp + fn) if (tp + fn) > 0 else 0
    rec_new = (tp + fp_nb) / (tp + fp_nb + fn) if (tp + fp_nb + fn) > 0 else 0

    return rec, prec, f1_orig, rec_new, prec_new, f1_new, pred

def calculate_performance_per_threhold(seed):
    full_mask = np.load(f"./output/arapiraca/arapiraca_mask_final.npy") # i think mask is not necessary for these metrics

    with open(f"./output/arapiraca/predictions/convlstm_i_arapiraca__{seed}.pkl", 'rb') as f:
        subgrid_indices = pickle.load(f)

    with open(f"./output/arapiraca/predictions/convlstm_predictions_arapiraca_{seed}.pkl", 'rb') as file:
        data_pred = pickle.load(file)

    with open(f"./output/arapiraca/predictions/convlstm_targets_arapiraca_{seed}.pkl", 'rb') as file:
        data_orig = pickle.load(file)
        
    print("All data opened!")

    originals = data_orig
    predictions = data_pred

    assert len(subgrid_indices) == predictions.shape[0], "Mismatch between subgrid indices and number of samples"

    
    perf_list = []

    for thr in np.arange(0.50, 1.01, 0.01):
        rec_list, prec_list, f1_list = [], [], []
        rec_new_list, prec_new_list, f1_new_list = [], [], []

        for sample in range(predictions.shape[0]):
            origi = originals[sample]
            predi = predictions[sample]
            predi2 = (predi >= thr).astype(int)

            top_i, top_j = subgrid_indices[sample]
            mask_subgrid = full_mask[top_i:top_i + 16, top_j:top_j + 16] 
                
            rec, prec, f1, rec_new, prec_new, f1_new, _ = get_custom_conf_matrix(
                origi, predi2, dist=1, mask=mask_subgrid
            )

            rec_list.append(rec)
            prec_list.append(prec)
            f1_list.append(f1)
            rec_new_list.append(rec_new)
            prec_new_list.append(prec_new)
            f1_new_list.append(f1_new)

        perf_list.append([
            thr,
            np.mean(rec_list), np.mean(prec_list), np.mean(f1_list),
            np.mean(rec_new_list), np.mean(prec_new_list), np.mean(f1_new_list)
        ])

    os.makedirs("./output/arapiraca/perf_thrs", exist_ok=True)
    output_path = f"./output/arapiraca/perf_thrs/convlstm_perf_thrs_arapiraca_{seed}.pkl"
    with open(output_path, "wb") as fp:
        pickle.dump(perf_list, fp)
    print(f"Saved performance metrics to {output_path}")
    
calculate_performance_per_threhold(seed = 42)
# Out:
# All data opened!
# Saved performance metrics to ./output/arapiraca/perf_thrs/convlstm_perf_thrs_arapiraca_42.pkl

# %% [markdown]
# ## 4. Visualização dos resultados
#
# Carrega e exibe as métricas de desempenho por threshold.

# %%
# Carrega e exibe as métricas salvas

import pickle
import pandas as pd
with open("./output/arapiraca/perf_thrs/convlstm_perf_thrs_arapiraca_42.pkl", "rb") as f:
    perf_data = pickle.load(f)
# Check what type it is and display it
print(type(perf_data))
if isinstance(perf_data, dict):
    for k, v in perf_data.items():
        print(f"{k}: {v}")
elif isinstance(perf_data, (pd.DataFrame, pd.Series)):
    display(perf_data)
else:
    display(perf_data)
# Out:
# <class 'list'>
# [[np.float64(0.5),
#   np.float64(0.4910194805194805),
#   np.float64(0.017924397227194706),
#   np.float64(0.032817413123145185),
#   np.float64(0.6150333597638721),
#   np.float64(0.12948601064476148),
#   np.float64(0.1977662230092109)],
#  [np.float64(0.51),
#   np.float64(0.4803427128427128),
#   np.float64(0.017989986994717287),
#   np.float64(0.032899757571611725),
#   np.float64(0.606198259475577),
#   np.float64(0.13062581534148993),
#   np.float64(0.1985309552883182)],
#  [np.float64(0.52),
#   np.float64(0.47273665223665223),
#   np.float64(0.01870196707523595),
#   np.float64(0.033657889765810106),
#   np.float64(0.5980871800303891),
#   np.float64(0.12994294719494004),
#   np.float64(0.19807298017031186)],
#  [np.float64(0.53),
#   np.float64(0.4674336219336219),
#   np.float64(0.019494660061654706),
#   np.float64(0.03466375919199596),
#   np.float64(0.5917463568146281),
#   np.float64(0.13210051168404452),
#   np.float64(0.19990015844293849)],
#  [np.float64(0.54),
#   np.float64(0.4610750360750361),
#   np.float64(0.01971265810347734),
#   np.float64(0.035033560860197925),
#   np.float64(0.5828595289101064),
#   np.float64(0.1328554935261547),
#   np.float64(0.20034658880483242)],
#  [np.float64(0.55),
#   np.float64(0.44769119769119764),
#   np.float64(0.019406160500663416),
#   np.float64(0.034753387185762666),
#   np.float64(0.5730778700458167),
#   np.float64(0.1337089142649606),
#   np.float64(0.20084960409757832)],
#  [np.float64(0.56),
#   np.float64(0.4377922077922078),
#   np.float64(0.019756931961891353),
#   np.float64(0.03523288024127058),
#   np.float64(0.5592427322601721),
#   np.float64(0.1343582053679432),
#   np.float64(0.20022711205786373)],
#  [np.float64(0.5700000000000001),
#   np.float64(0.42918614718614717),
#   np.float64(0.020391413694604763),
#   np.float64(0.03616809570131949),
#   np.float64(0.5503940801059714),
#   np.float64(0.13675288075161895),
#   np.float64(0.20182579036500709)],
#  [np.float64(0.5800000000000001),
#   np.float64(0.4237821067821068),
#   np.float64(0.020601958473904867),
#   np.float64(0.036827906461875275),
#   np.float64(0.5427621991055308),
#   np.float64(0.13850464751709143),
#   np.float64(0.20320033911741528)],
#  [np.float64(0.5900000000000001),
#   np.float64(0.41635786435786437),
#   np.float64(0.02228578732790488),
#   np.float64(0.03854212434167872),
#   np.float64(0.533011633426593),
#   np.float64(0.14110889948972347),
#   np.float64(0.2051739446710133)],
#  [np.float64(0.6000000000000001),
#   np.float64(0.39992352092352096),
#   np.float64(0.022044188051465467),
#   np.float64(0.038381399622661766),
#   np.float64(0.5169772637753086),
#   np.float64(0.1414606115017249),
#   np.float64(0.20436063608986277)],
#  [np.float64(0.6100000000000001),
#   np.float64(0.3872467532467533),
#   np.float64(0.021043231085046125),
#   np.float64(0.03724038876969001),
#   np.float64(0.50375980847216),
#   np.float64(0.1426201580744263),
#   np.float64(0.20400085199754164)],
#  [np.float64(0.6200000000000001),
#   np.float64(0.3714076479076478),
#   np.float64(0.021176906726192848),
#   np.float64(0.03757793279575476),
#   np.float64(0.4945892448451375),
#   np.float64(0.14594840761623976),
#   np.float64(0.2065504903727616)],
#  [np.float64(0.6300000000000001),
#   np.float64(0.3583614718614719),
#   np.float64(0.021311736361879552),
#   np.float64(0.037838656291870554),
#   np.float64(0.4828478419946848),
#   np.float64(0.14687056137122237),
#   np.float64(0.20659760193033985)],
#  [np.float64(0.6400000000000001),
#   np.float64(0.3456038961038961),
#   np.float64(0.022229936714215),
#   np.float64(0.03847826714732147),
#   np.float64(0.47008304551515395),
#   np.float64(0.14912042634058856),
#   np.float64(0.2064343749643246)],
#  [np.float64(0.6500000000000001),
#   np.float64(0.32972510822510825),
#   np.float64(0.022702367219268705),
#   np.float64(0.03871736787990422),
#   np.float64(0.4552973767048696),
#   np.float64(0.14807006593042338),
#   np.float64(0.20502208956596343)],
#  [np.float64(0.6600000000000001),
#   np.float64(0.3128968253968254),
#   np.float64(0.021200759406175468),
#   np.float64(0.037616678553241356),
#   np.float64(0.439812728131813),
#   np.float64(0.14710362870667018),
#   np.float64(0.2025365069745637)],
#  [np.float64(0.6700000000000002),
#   np.float64(0.30203823953823955),
#   np.float64(0.022728825490202675),
#   np.float64(0.03965083103982216),
#   np.float64(0.4283363098542124),
#   np.float64(0.14960205082827388),
#   np.float64(0.20359514360219746)],
#  [np.float64(0.6800000000000002),
#   np.float64(0.288482683982684),
#   np.float64(0.023531774073249072),
#   np.float64(0.04047236114078952),
#   np.float64(0.4143083444671676),
#   np.float64(0.1514557732357238),
#   np.float64(0.2031991757590768)],
#  [np.float64(0.6900000000000002),
#   np.float64(0.27114935064935064),
#   np.float64(0.025092717229556968),
#   np.float64(0.041672646716390455),
#   np.float64(0.39897645346799204),
#   np.float64(0.15122938642944558),
#   np.float64(0.20128633485665445)],
#  [np.float64(0.7000000000000002),
#   np.float64(0.25352741702741705),
#   np.float64(0.024827574926231773),
#   np.float64(0.04080552378880745),
#   np.float64(0.38443797866432816),
#   np.float64(0.15299287303907905),
#   np.float64(0.2006167990867527)],
#  [np.float64(0.7100000000000002),
#   np.float64(0.23889105339105338),
#   np.float64(0.026103596879334307),
#   np.float64(0.04140336329183729),
#   np.float64(0.3684630590290358),
#   np.float64(0.1545193116719741),
#   np.float64(0.19895210806970928)],
#  [np.float64(0.7200000000000002),
#   np.float64(0.22068903318903318),
#   np.float64(0.02448865488764841),
#   np.float64(0.039523005012199436),
#   np.float64(0.348148142014837),
#   np.float64(0.1513141489885354),
#   np.float64(0.19314275451644541)],
#  [np.float64(0.7300000000000002),
#   np.float64(0.2059314574314574),
#   np.float64(0.024491529154396008),
#   np.float64(0.039009229361402616),
#   np.float64(0.3293454875136211),
#   np.float64(0.1506008643102126),
#   np.float64(0.18884408768817704)],
#  [np.float64(0.7400000000000002),
#   np.float64(0.18534848484848485),
#   np.float64(0.02372909164161107),
#   np.float64(0.0374938949537923),
#   np.float64(0.3113541432849089),
#   np.float64(0.14936505694183283),
#   np.float64(0.18456832435053044)],
#  [np.float64(0.7500000000000002),
#   np.float64(0.1691305916305916),
#   np.float64(0.02311788230376809),
#   np.float64(0.036202363628753446),
#   np.float64(0.29395901000246255),
#   np.float64(0.1486672526931626),
#   np.float64(0.1807940041185537)],
#  [np.float64(0.7600000000000002),
#   np.float64(0.15695887445887444),
#   np.float64(0.02384800555423244),
#   np.float64(0.03635651475893114),
#   np.float64(0.27702102071093676),
#   np.float64(0.15113851109300677),
#   np.float64(0.17816809835683306)],
#  [np.float64(0.7700000000000002),
#   np.float64(0.14196897546897547),
#   np.float64(0.022734156312539677),
#   np.float64(0.034715097685621685),
#   np.float64(0.256406829650291),
#   np.float64(0.14496068158044423),
#   np.float64(0.17013898341310754)],
#  [np.float64(0.7800000000000002),
#   np.float64(0.1255793650793651),
#   np.float64(0.022184329199041418),
#   np.float64(0.032653968335505476),
#   np.float64(0.23675347076123884),
#   np.float64(0.14307369257514127),
#   np.float64(0.1632321091776752)],
#  [np.float64(0.7900000000000003),
#   np.float64(0.11588239538239538),
#   np.float64(0.0228534064905159),
#   np.float64(0.03293194684833986),
#   np.float64(0.21808804728187),
#   np.float64(0.13855205799647288),
#   np.float64(0.15518392961644248)],
#  [np.float64(0.8000000000000003),
#   np.float64(0.09874963924963924),
#   np.float64(0.020707038452230153),
#   np.float64(0.029436985467360878),
#   np.float64(0.1965194328436567),
#   np.float64(0.13271144018552425),
#   np.float64(0.14513258716148966)],
#  [np.float64(0.8100000000000003),
#   np.float64(0.0843051948051948),
#   np.float64(0.020104818062909993),
#   np.float64(0.027262662784008535),
#   np.float64(0.17597490084578463),
#   np.float64(0.128421108385343),
#   np.float64(0.13563264284433799)],
#  [np.float64(0.8200000000000003),
#   np.float64(0.07156277056277056),
#   np.float64(0.01872865200962061),
#   np.float64(0.025064723153530904),
#   np.float64(0.15991513475526986),
#   np.float64(0.12520867145181971),
#   np.float64(0.12768496214670402)],
#  [np.float64(0.8300000000000003),
#   np.float64(0.06184054834054834),
#   np.float64(0.017221609223676677),
#   np.float64(0.02257232613937195),
#   np.float64(0.14000671861521846),
#   np.float64(0.11439248870634228),
#   np.float64(0.11516098694793882)],
#  [np.float64(0.8400000000000003),
#   np.float64(0.05293578643578643),
#   np.float64(0.017002341986077918),
#   np.float64(0.020918595568597407),
#   np.float64(0.12103384535167536),
#   np.float64(0.10581697284959983),
#   np.float64(0.1033049367623739)],
#  [np.float64(0.8500000000000003),
#   np.float64(0.04266305916305916),
#   np.float64(0.01550782001821968),
#   np.float64(0.01804734540255533),
#   np.float64(0.10172417392470869),
#   np.float64(0.09528455032684709),
#   np.float64(0.09013310899953157)],
#  [np.float64(0.8600000000000003),
#   np.float64(0.037137806637806636),
#   np.float64(0.014741322364035565),
#   np.float64(0.016710223511695627),
#   np.float64(0.08619108500926682),
#   np.float64(0.08765387859005927),
#   np.float64(0.07936258120480787)],
#  [np.float64(0.8700000000000003),
#   np.float64(0.030980519480519483),
#   np.float64(0.012659366727548546),
#   np.float64(0.01552243809603787),
#   np.float64(0.0726828995919905),
#   np.float64(0.07646914221646842),
#   np.float64(0.06909902868110547)],
#  [np.float64(0.8800000000000003),
#   np.float64(0.0233989898989899),
#   np.float64(0.011506012506012506),
#   np.float64(0.013800845296201335),
#   np.float64(0.05929008365372001),
#   np.float64(0.07042167198387295),
#   np.float64(0.05964512527115961)],
#  [np.float64(0.8900000000000003),
#   np.float64(0.015833333333333335),
#   np.float64(0.008315055315055313),
#   np.float64(0.009760264295023654),
#   np.float64(0.04372453976999432),
#   np.float64(0.05943484629848266),
#   np.float64(0.04666759850489461)],
#  [np.float64(0.9000000000000004),
#   np.float64(0.013005050505050504),
#   np.float64(0.008064454064454064),
#   np.float64(0.009119301573847029),
#   np.float64(0.03331553631553632),
#   np.float64(0.04861495911495912),
#   np.float64(0.03731483464258584)],
#  [np.float64(0.9100000000000004),
#   np.float64(0.008772727272727272),
#   np.float64(0.007484848484848486),
#   np.float64(0.006821111548384277),
#   np.float64(0.02093217893217893),
#   np.float64(0.036722222222222226),
#   np.float64(0.02507210802665348)],
#  [np.float64(0.9200000000000004),
#   np.float64(0.00502020202020202),
#   np.float64(0.00401010101010101),
#   np.float64(0.003988936988936989),
#   np.float64(0.012486291486291486),
#   np.float64(0.025494949494949494),
#   np.float64(0.01578140378140378)],
#  [np.float64(0.9300000000000004),
#   np.float64(0.0037070707070707065),
#   np.float64(0.004292929292929293),
#   np.float64(0.0034689754689754683),
#   np.float64(0.006434343434343435),
#   np.float64(0.011818181818181818),
#   np.float64(0.007942279942279942)],
#  [np.float64(0.9400000000000004),
#   np.float64(0.003),
#   np.float64(0.004696969696969697),
#   np.float64(0.003264069264069264),
#   np.float64(0.0038383838383838375),
#   np.float64(0.007070707070707071),
#   np.float64(0.004727272727272727)],
#  [np.float64(0.9500000000000004),
#   np.float64(0.00101010101010101),
#   np.float64(0.0018181818181818182),
#   np.float64(0.0012121212121212121),
#   np.float64(0.0013131313131313131),
#   np.float64(0.0024242424242424242),
#   np.float64(0.0016161616161616162)],
#  [np.float64(0.9600000000000004),
#   np.float64(0.00020202020202020202),
#   np.float64(0.0006060606060606061),
#   np.float64(0.00030303030303030303),
#   np.float64(0.00020202020202020202),
#   np.float64(0.0006060606060606061),
#   np.float64(0.00030303030303030303)],
#  [np.float64(0.9700000000000004),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0)],
#  [np.float64(0.9800000000000004),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0)],
#  [np.float64(0.9900000000000004),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0)],
#  [np.float64(1.0000000000000004),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0),
#   np.float64(0.0)]]

# %% [markdown]
# ## 5. Análise detalhada
#
# Exibe os resultados em formato de tabela e identifica os melhores thresholds.

# %%
# Exibe resultados em DataFrame e identifica os melhores thresholds
# para F1 tradicional e F1 espacial

import pickle
import pandas as pd
with open("./output/arapiraca/perf_thrs/convlstm_perf_thrs_arapiraca_42.pkl", "rb") as f:
    perf_list = pickle.load(f)
df_perf = pd.DataFrame(perf_list, columns=[
    "threshold", "recall", "precision", "f1",
    "recall_spatial", "precision_spatial", "f1_spatial"
])
display(df_perf)
# Find best threshold by F1
best_row = df_perf.loc[df_perf["f1_spatial"].idxmax()]
print(f"\nBest threshold: {best_row['threshold']:.2f}")
print(f"  Recall (spatial):    {best_row['recall_spatial']:.4f}")
print(f"  Precision (spatial): {best_row['precision_spatial']:.4f}")
print(f"  F1 (spatial):        {best_row['f1_spatial']:.4f}")
# Out:
#     threshold    recall  precision        f1  recall_spatial  \
# 0        0.50  0.491019   0.017924  0.032817        0.615033
# 1        0.51  0.480343   0.017990  0.032900        0.606198
# 2        0.52  0.472737   0.018702  0.033658        0.598087
# 3        0.53  0.467434   0.019495  0.034664        0.591746
# 4        0.54  0.461075   0.019713  0.035034        0.582860
# 5        0.55  0.447691   0.019406  0.034753        0.573078
# 6        0.56  0.437792   0.019757  0.035233        0.559243
# 7        0.57  0.429186   0.020391  0.036168        0.550394
# 8        0.58  0.423782   0.020602  0.036828        0.542762
# 9        0.59  0.416358   0.022286  0.038542        0.533012
# 10       0.60  0.399924   0.022044  0.038381        0.516977
# 11       0.61  0.387247   0.021043  0.037240        0.503760
# 12       0.62  0.371408   0.021177  0.037578        0.494589
# 13       0.63  0.358361   0.021312  0.037839        0.482848
# 14       0.64  0.345604   0.022230  0.038478        0.470083
# 15       0.65  0.329725   0.022702  0.038717        0.455297
# 16       0.66  0.312897   0.021201  0.037617        0.439813
# 17       0.67  0.302038   0.022729  0.039651        0.428336
# 18       0.68  0.288483   0.023532  0.040472        0.414308
# 19       0.69  0.271149   0.025093  0.041673        0.398976
# 20       0.70  0.253527   0.024828  0.040806        0.384438
# 21       0.71  0.238891   0.026104  0.041403        0.368463
# 22       0.72  0.220689   0.024489  0.039523        0.348148
# 23       0.73  0.205931   0.024492  0.039009        0.329345
# 24       0.74  0.185348   0.023729  0.037494        0.311354
# 25       0.75  0.169131   0.023118  0.036202        0.293959
# 26       0.76  0.156959   0.023848  0.036357        0.277021
# 27       0.77  0.141969   0.022734  0.034715        0.256407
# 28       0.78  0.125579   0.022184  0.032654        0.236753
# 29       0.79  0.115882   0.022853  0.032932        0.218088
# 30       0.80  0.098750   0.020707  0.029437        0.196519
# 31       0.81  0.084305   0.020105  0.027263        0.175975
# 32       0.82  0.071563   0.018729  0.025065        0.159915
# 33       0.83  0.061841   0.017222  0.022572        0.140007
# 34       0.84  0.052936   0.017002  0.020919        0.121034
# 35       0.85  0.042663   0.015508  0.018047        0.101724
# 36       0.86  0.037138   0.014741  0.016710        0.086191
# 37       0.87  0.030981   0.012659  0.015522        0.072683
# 38       0.88  0.023399   0.011506  0.013801        0.059290
# 39       0.89  0.015833   0.008315  0.009760        0.043725
# 40       0.90  0.013005   0.008064  0.009119        0.033316
# 41       0.91  0.008773   0.007485  0.006821        0.020932
# 42       0.92  0.005020   0.004010  0.003989        0.012486
# 43       0.93  0.003707   0.004293  0.003469        0.006434
# 44       0.94  0.003000   0.004697  0.003264        0.003838
# 45       0.95  0.001010   0.001818  0.001212        0.001313
# 46       0.96  0.000202   0.000606  0.000303        0.000202
# 47       0.97  0.000000   0.000000  0.000000        0.000000
# 48       0.98  0.000000   0.000000  0.000000        0.000000
# 49       0.99  0.000000   0.000000  0.000000        0.000000
# 50       1.00  0.000000   0.000000  0.000000        0.000000
#
#     precision_spatial  f1_spatial
# 0            0.129486    0.197766
# 1            0.130626    0.198531
# 2            0.129943    0.198073
# 3            0.132101    0.199900
# 4            0.132855    0.200347
# 5            0.133709    0.200850
# 6            0.134358    0.200227
# 7            0.136753    0.201826
# 8            0.138505    0.203200
# 9            0.141109    0.205174
# 10           0.141461    0.204361
# 11           0.142620    0.204001
# 12           0.145948    0.206550
# 13           0.146871    0.206598
# 14           0.149120    0.206434
# 15           0.148070    0.205022
# 16           0.147104    0.202537
# 17           0.149602    0.203595
# 18           0.151456    0.203199
# 19           0.151229    0.201286
# 20           0.152993    0.200617
# 21           0.154519    0.198952
# 22           0.151314    0.193143
# 23           0.150601    0.188844
# 24           0.149365    0.184568
# 25           0.148667    0.180794
# 26           0.151139    0.178168
# 27           0.144961    0.170139
# 28           0.143074    0.163232
# 29           0.138552    0.155184
# 30           0.132711    0.145133
# 31           0.128421    0.135633
# 32           0.125209    0.127685
# 33           0.114392    0.115161
# 34           0.105817    0.103305
# 35           0.095285    0.090133
# 36           0.087654    0.079363
# 37           0.076469    0.069099
# 38           0.070422    0.059645
# 39           0.059435    0.046668
# 40           0.048615    0.037315
# 41           0.036722    0.025072
# 42           0.025495    0.015781
# 43           0.011818    0.007942
# 44           0.007071    0.004727
# 45           0.002424    0.001616
# 46           0.000606    0.000303
# 47           0.000000    0.000000
# 48           0.000000    0.000000
# 49           0.000000    0.000000
# 50           0.000000    0.000000
# Best threshold: 0.63
#   Recall (spatial):    0.4828
#   Precision (spatial): 0.1469
#   F1 (spatial):        0.2066
